# %%
import networkx as nx


"""
G=nx.Graph()
G.add_node(1)
G.add_nodes_from([2,3])
H=nx.path_graph(10)
G.add_nodes_from(H)
G.add_edge(1,2)
e=(2,3)
G.add_edge(*e)
G.neighbors(1)
"""
# Out:
# '\nG=nx.Graph()\nG.add_node(1)\nG.add_nodes_from([2,3])\nH=nx.path_graph(10)\nG.add_nodes_from(H)\nG.add_edge(1,2)\ne=(2,3)\nG.add_edge(*e)\nG.neighbors(1)\n'

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(G)

# %%
plt.show()

# %%
G=nx.Graph()
G.add_nodes_from((0, 1 , 2, 3, 4)) 
nodes = G.nodes()
print("len nodes {}".format(len(nodes)))

"""
pos={nodes[0]: (.1, .1),
    nodes[1]: (.2, .2),
    nodes[2]: (.3, .3),
    nodes[3]: (.4, .4),
    nodes[4]: (.5, .5)}

labels={nodes[0]:"d",
    nodes[1]: "j",
    nodes[2]: "i",
    nodes[3]:"n",
    nodes[4]:"s"}
"""
G.add_edge(nodes[0],nodes[1])
G.add_edge(nodes[0],nodes[2])
G.add_edge(nodes[0],nodes[3])
G.add_edge(nodes[3],nodes[4])

#nx.draw_networkx_labels(G, pos, labels)
nx.draw(G)
plt.show()
# Out:
# len nodes 5

# %%
G.neighbors(nodes[0])
# Out:
# [1, 2, 3]

# %%
for path in nx.all_simple_paths(G, nodes[4], nodes[1]):
   
    print(path)
# Out:
# [4, 3, 0, 1]
